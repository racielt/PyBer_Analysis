# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
temp = [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2]
sales = [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]

# %%
# Tell matplotlib to create a scatter plot based upon the above data
plt.scatter(temp,sales,facecolor="red",edgecolor="black",s=20, alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Set the upper and lower limits of our y axis
plt.ylim(min(sales)-5,max(sales)+5)
# Out:
# (180.0, 619.0)

# %%
# Set the upper and lower limits of our x
plt.xlim(min(temp)-5,max(temp)+5)
# Out:
# (6.9, 30.1)

# %%
# Create a title, x label, and y label for our chart
plt.title("Icecream_sales")
plt.xlabel("temp (C)")
plt.ylabel("sales ($)")
# Out:
# Text(76.56944444444443, 0.5, 'sales ($)')

# %%
#Save an image of our chart and print the final product to the screen
plt.savefig("../icecream.png")
plt.show()
